# %%
# !pip install -r ../../../requirements.txt --quiet
# !pip install ../../../ --quiet

# %% [markdown]
# # VFBTerm DataSet Methods
# This notebook demonstrates the usage of the `vfb.term` and `vfb.terms` methods for accessing VFB term information.
# We'll explore how to create `VFBTerm` objects, access related terms, images, and use advanced features like lazy loading of parents and manipulating collections of terms with `VFBTerms`.

# %%
# Import the VFBConnect class
from vfb_connect import vfb

vfb._load_limit = 10 # Limit the number of results returned to speed things up
# Out:
# Welcome to the Virtual Fly Brain API
# See the documentation at: https://virtualflybrain.org/docs/tutorials/apis/
#
# Establishing connections to https://VirtualFlyBrain.org services...
# Session Established!
#
# Type vfb. and press tab to see available queries. You can run help against any query e.g. help(vfb.terms)

# %% [markdown]
# ## Creating and Exploring VFBTerm DataSet Objects
# We'll start by creating a `VFBTerm` object using the `vfb.term` method.

# %%
# Example of creating a VFBTerm object using a term name
vfb_dataset = vfb.term('EM FAFB Engert et al. 2022')
vfb_dataset
# Out:
# VFBTerm(term=Term(term=MinimalEntityInfo(name=EM FAFB Engert et al. 2022, short_form=Engert2022), link=https://n2t.net/vfb:Engert2022))

# %%
vfb_dataset.summary
# Out:
#            ID                        Name  \
# 0  Engert2022  EM FAFB Engert et al. 2022
#
#                                          Description  \
# 0  FAFB EM reconstructed neurons from Engert et a...
#
#                               URL                       Counts  \
# 0  https://n2t.net/vfb:Engert2022  {'images': 144, 'types': 5}
#
#                               Publications    License  \
# 0  [Engert et al., 2022, eLife 11: e78110]  CC-BY_4.0
#
#                                     Cross References
# 0  [https://fafb.catmaid.virtualflybrain.org/?pid...

# %%
vfb_dataset.publications
# Out:
# [Publication(pub=MinimalEntityInfo(name=Engert et al., 2022, eLife 11: e78110, short_form=FBrf0253662), link=http://flybase.org/reports/FBrf0253662)]

# %%
vfb_dataset.license
# Out:
# Term(term=MinimalEntityInfo(name=CC-BY_4.0, short_form=VFBlicense_CC_BY_4_0), link=https://creativecommons.org/licenses/by/4.0/legalcode)

# %%
vfb_dataset.counts
# Out:
# {'images': 144, 'types': 5}

# %%
vfb_dataset.xrefs
# Out:
# [Xref(link_text=EM FAFB Engert et al. 2022 on VFB CATMAID Adult Brain (FAFB), link=https://fafb.catmaid.virtualflybrain.org/?pid=1&tool=tracingtool&sid0=1&s0=2&active_skeleton_id=17682008, accession=17682008)]

# %%
vfb_dataset.instances
# Out:
# Loading instances for the first time...
# Loading 144 instances for dataset: EM FAFB Engert et al. 2022...
# Loading terms:   7%|▋         | 10/144 [00:16<03:38,  1.63s/it]
# Reached load limit of 10. Stopping.
# VFBTerms(terms=[VFBTerm(term=Term(term=MinimalEntityInfo(name=GRN L4#1 (FAFB:10154803), short_form=VFB_001029ja), link=https://n2t.net/vfb:VFB_001029ja)), VFBTerm(term=Term(term=MinimalEntityInfo(name=GRN R4#17 (FAFB:14947934), short_form=VFB_001029l6), link=https://n2t.net/vfb:VFB_001029l6)), VFBTerm(term=Term(term=MinimalEntityInfo(name=GRN R4#6 (FAFB:7471728), short_form=VFB_001029ic), link=https://n2t.net/vfb:VFB_001029ic)), VFBTerm(term=Term(term=MinimalEntityInfo(name=GRN R6#17 (FAFB:11559900), short_form=VFB_001029kj), link=https://n2t.net/vfb:VFB_001029kj)), VFBTerm(term=Term(term=MinimalEntityInfo(name=GRN L4#15 (FAFB:16149178), short_form=VFB_001029ly), link=https://n2t.net/vfb:VFB_001029ly)), VFBTerm(term=Term(term=MinimalEntityInfo(name=GRN L7#9 (FAFB:16149059), short_form=VFB_001029lg), link=https://n2t.net/vfb:VFB_001029lg)), VFBTerm(term=Term(term=MinimalEntityInfo(name=GRN R6#9 (FAFB:9235133), short_form=VFB_001029j7), link=https://n2t.net/vfb:VFB_001029j7)), VFBTerm(term=Term(term=MinimalEntityInfo(name=GRN L1#4 (FAFB:10796200), short_form=VFB_001029jr), link=https://n2t.net/vfb:VFB_001029jr)), VFBTerm(term=Term(term=MinimalEntityInfo(name=GRN R5#4 (FAFB:7479777), short_form=VFB_001029if), link=https://n2t.net/vfb:VFB_001029if)), VFBTerm(term=Term(term=MinimalEntityInfo(name=GRN L1#2 (FAFB:10603489), short_form=VFB_001029jj), link=https://n2t.net/vfb:VFB_001029jj))])

# %%
vfb_dataset.instances.get_summaries()
# Out:
#              ID                       Name               Description  \
# 0  VFB_001029ja   GRN L4#1 (FAFB:10154803)   GRN L4#1, FBbt:00110887
# 1  VFB_001029l6  GRN R4#17 (FAFB:14947934)  GRN R4#17, FBbt:00058156
# 2  VFB_001029ic    GRN R4#6 (FAFB:7471728)   GRN R4#6, FBbt:00058156
# 3  VFB_001029kj  GRN R6#17 (FAFB:11559900)  GRN R6#17, FBbt:00100042
# 4  VFB_001029ly  GRN L4#15 (FAFB:16149178)  GRN L4#15, FBbt:00110887
# 5  VFB_001029lg   GRN L7#9 (FAFB:16149059)   GRN L7#9, FBbt:00110887
# 6  VFB_001029j7    GRN R6#9 (FAFB:9235133)   GRN R6#9, FBbt:00100042
# 7  VFB_001029jr   GRN L1#4 (FAFB:10796200)   GRN L1#4, FBbt:00048152
# 8  VFB_001029if    GRN R5#4 (FAFB:7479777)   GRN R5#4, FBbt:00058156
# 9  VFB_001029jj   GRN L1#2 (FAFB:10603489)   GRN L1#2, FBbt:00048152
#
#                                 URL  \
# 0  https://n2t.net/vfb:VFB_001029ja
# 1  https://n2t.net/vfb:VFB_001029l6
# 2  https://n2t.net/vfb:VFB_001029ic
# 3  https://n2t.net/vfb:VFB_001029kj
# 4  https://n2t.net/vfb:VFB_001029ly
# 5  https://n2t.net/vfb:VFB_001029lg
# 6  https://n2t.net/vfb:VFB_001029j7
# 7  https://n2t.net/vfb:VFB_001029jr
# 8  https://n2t.net/vfb:VFB_001029if
# 9  https://n2t.net/vfb:VFB_001029jj
#
#                                        Related Terms  \
# 0  [Rel(relation=MinimalEdgeInfo(label=is part of...
# 1  [Rel(relation=MinimalEdgeInfo(label=is part of...
# 2  [Rel(relation=MinimalEdgeInfo(label=is part of...
# 3  [Rel(relation=MinimalEdgeInfo(label=is part of...
# 4  [Rel(relation=MinimalEdgeInfo(label=is part of...
# 5  [Rel(relation=MinimalEdgeInfo(label=is part of...
# 6  [Rel(relation=MinimalEdgeInfo(label=is part of...
# 7  [Rel(relation=MinimalEdgeInfo(label=is part of...
# 8  [Rel(relation=MinimalEdgeInfo(label=is part of...
# 9  [Rel(relation=MinimalEdgeInfo(label=is part of...
#
#                                              Parents    License  \
# 0        [gustatory receptor neuron of the labellum]  CC-BY_4.0
# 1   [sugar-sensing neuron of labellar taste bristle]  CC-BY_4.0
# 2   [sugar-sensing neuron of labellar taste bristle]  CC-BY_4.0
# 3   [water-sensing neuron of labellar taste bristle]  CC-BY_4.0
# 4        [gustatory receptor neuron of the labellum]  CC-BY_4.0
# 5        [gustatory receptor neuron of the labellum]  CC-BY_4.0
# 6   [water-sensing neuron of labellar taste bristle]  CC-BY_4.0
# 7  [bitter-sensing neuron of labellar taste bristle]  CC-BY_4.0
# 8   [sugar-sensing neuron of labellar taste bristle]  CC-BY_4.0
# 9  [bitter-sensing neuron of labellar taste bristle]  CC-BY_4.0
#
#                                     Cross References  \
# 0  [https://fafb.catmaid.virtualflybrain.org/?pid...
# 1  [https://fafb.catmaid.virtualflybrain.org/?pid...
# 2  [https://fafb.catmaid.virtualflybrain.org/?pid...
# 3  [https://fafb.catmaid.virtualflybrain.org/?pid...
# 4  [https://fafb.catmaid.virtualflybrain.org/?pid...
# 5  [https://fafb.catmaid.virtualflybrain.org/?pid...
# 6  [https://fafb.catmaid.virtualflybrain.org/?pid...
# 7  [https://fafb.catmaid.virtualflybrain.org/?pid...
# 8  [https://fafb.catmaid.virtualflybrain.org/?pid...
# 9  [https://fafb.catmaid.virtualflybrain.org/?pid...
#
#                        Datasets
# 0  [EM FAFB Engert et al. 2022]
# 1  [EM FAFB Engert et al. 2022]
# 2  [EM FAFB Engert et al. 2022]
# 3  [EM FAFB Engert et al. 2022]
# 4  [EM FAFB Engert et al. 2022]
# 5  [EM FAFB Engert et al. 2022]
# 6  [EM FAFB Engert et al. 2022]
# 7  [EM FAFB Engert et al. 2022]
# 8  [EM FAFB Engert et al. 2022]
# 9  [EM FAFB Engert et al. 2022]

# %%
vfb_dataset.show()
# Out:
# Loading thumbnail for GRN L4#1 (FAFB:10154803)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1212x566>

# %%
vfb_dataset.open(verbose=True)
# Out:
# Opening  https://n2t.net/vfb:Engert2022

# %%
a=vfb_dataset.instances[5]

print(a.name)

a.channel_images[0].image.show()
# Out:
# GRN L7#9 (FAFB:16149059)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1212x566>

# %%
vfb_dataset.plot3d()
# Out:
# Defaulting to JRC2018Unisex template
# Enforcing the display template space as JRC2018Unisex from the first skeleton found. Specify a template to avoid this.
# Plotting 3D representation of 10 items

# %% [markdown]
# Please see [VFBTerm Notebook](vfb_terms.html) for examples of how to load specific sets of terms and display neurons in context
